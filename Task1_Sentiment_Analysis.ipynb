# %% [markdown]
# <a href="https://colab.research.google.com/github/Navya-2401/Slash-Mark/blob/main/Task1_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report


nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Abhayparashar31/NLPP_sentiment-analsis-on-hotel-review/main/Restaurant_Reviews.tsv'

df = pd.read_csv(url, delimiter='\t', quoting=3)

print("Dataset size:", df.shape)
df.head()
# Out:
# Dataset size: (1000, 2)
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
corpus = []

for i in range(len(df)):

    review = re.sub('[^a-zA-Z]', ' ', df['Review'][i])
    review = review.lower().split()
    review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

print("Text cleaning complete!")
print("Example of a cleaned review:", corpus[0])
# Out:
# Text cleaning complete!
# Example of a cleaned review: wow loved place

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=1500)

X = tfidf.fit_transform(corpus).toarray()
y = df['Liked'].values

print("Words successfully converted to numbers!")
print("Shape of our new math matrix:", X.shape)
# Out:
# Words successfully converted to numbers!
# Shape of our new math matrix: (1000, 1500)

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

model = SVC(kernel='linear', random_state=42)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Model Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.77
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.84      0.78        96
#            1       0.83      0.70      0.76       104
#
#     accuracy                           0.77       200
#    macro avg       0.78      0.77      0.77       200
# weighted avg       0.78      0.77      0.77       200

# %%
def test_my_review(my_review):
    clean_review = re.sub('[^a-zA-Z]', ' ', my_review)
    clean_review = clean_review.lower().split()
    clean_review = [lemmatizer.lemmatize(word) for word in clean_review if word not in set(stopwords.words('english'))]
    clean_review = ' '.join(clean_review)

    review_numbers = tfidf.transform([clean_review]).toarray()

    prediction = model.predict(review_numbers)

    if prediction[0] == 1:
        print(f"'{my_review}' ---> POSITIVE 😊")
    else:
        print(f"'{my_review}' ---> NEGATIVE 😠")

test_my_review("The food was absolutely incredible and the waiter was so nice!")
test_my_review("I waited an hour for cold soup. Never going back.")

test_my_review("Put your own custom sentence right here!")
# Out:
# 'The food was absolutely incredible and the waiter was so nice!' ---> POSITIVE 😊
# 'I waited an hour for cold soup. Never going back.' ---> NEGATIVE 😠
# 'Put your own custom sentence right here!' ---> NEGATIVE 😠
